# %% [markdown]
# <a href="https://colab.research.google.com/github/Baghatraj/Mobile-Application-Lab/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints)

# %%
plt.plot([0,8],[0,64])

# %%
xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints,'o')

# %%
plt.plot([0,6],[1,10],'o')

# %%
plt.plot([0,1,2,4,5,],[3,8,7,9,3],'*')

# %%
plt.plot([0,1,2,4,5,],[3,8,7,9,3],'--')

# %%
plt.plot([0,1,2,4,5,],[3,8,7,9,3],'1')

# %%
plt.plot([0,1,2,4,5,],[3,8,7,9,3],'.')

# %%
plt.plot([0,1,2,4,5,],[3,8,7,9,3])

# %%
ypoints=np.array([0,30,70,250])

plt.plot(ypoints)

# %%
ypoints=np.array([0,30,70,250])

plt.plot(ypoints,marker='*')

# %%
ypoints=np.array([0,30,70,250])

plt.plot(ypoints,'*:k')

# %%
ypoints=np.array([0,30,70,15,45,200,250])

plt.plot(ypoints,marker='o',ms=20,mec='k',mfc='r')

# %%
ypoints=np.array([0,30,70,15,45,200,250])

plt.plot(ypoints,'*:k',ms=20,mec='k',mfc='r')

# %%
ypoints=np.array([0,30,70,15,45,200,250])

plt.plot(ypoints,linestyle='--')

# %%
ypoints=np.array([0,30,70,15,45,200,250])

plt.plot(ypoints,color='r',lw='22')

# %%
y1=np.array([0,30,70,15,45,200,250])
y2=np.array([2,35,76,150,175,225])
plt.plot(y1)
plt.plot(y2)

# %%
x1=np.array([0,25,50,55])
y1=np.array([0,36,55,60])
x2=np.array([0,15,30,45])
y2=np.array([0,25,40,35])

plt.plot(x1,y1,x2,y2)
